# %%
import numpy as np
import pandas as pd
import os

# %%
# /ssd8/ming/covid_challenge/output/cnn_10_total_pred_df.csv #ECA-NFNET

#eff_mix_conv_E = pd.read_csv('./csv_pickle/1d_2d_cnn_weight_from_sz384_144server/eff_conv_mix_E_384_check01.csv')
#eff_mix_conv_S = pd.read_csv('./csv_pickle/1d_2d_cnn_weight_from_sz384_144server/eff_conv_mix_S_384_check01.csv')

# submit1 = eff-mix-conv-E [0.5]
# submit2 = eff-mix-conv-S [0.5]
# submit3 = ECA-NFnet CV   [0.5]
# submit4 = eff-mix-conv-E + eff-mix-conv-S + ECA-NFnet CV [0.5]
# submit5 = eff-mix-conv-E + eff-mix-conv-S + ECA-NFnet CV [0.522]

# %%
eff_0 = pd.read_csv('/ssd2/ming/2024COVID/output/cnn_10_total_pred_df.csv')
eff_0 = eff_0[['path','total_pred']]
new_path =[]
for i in eff_0.path.values:
    path_ = i.split('/')[-1]
    new_path.append(path_)
eff_0['path'] = new_path
eff_0 = eff_0.sort_values('path').rename(columns={"path":"name","total_pred":"pred"})
file="Submission1"
use_df=eff_0
folder_path="/ssd2/ming/2024COVID/submission"+"/"+file
if not os.path.exists(folder_path):
    os.makedirs(folder_path)
use_df["name"]=use_df["name"].apply(lambda x : x.split("/")[-1])
covid_ct=use_df[use_df["pred"]>0.5].name.values
non_covid_ct=use_df[use_df["pred"]<0.5].name.values

covid_df=pd.DataFrame(covid_ct,columns=["ct_name"])
non_covid_df=pd.DataFrame(non_covid_ct,columns=["ct_name"])
covid_df.sort_values(by=['ct_name'],inplace=True)
non_covid_df.sort_values(by=['ct_name'],inplace=True)

covid_df.to_csv(f"{folder_path}/covid.csv",header=False,index=False)
non_covid_df.to_csv(f"{folder_path}/non-covid.csv",header=False,index=False)
print("covid:",len(covid_df) , "  non_covid:",len(non_covid_df))
# Out:
# covid: 563   non_covid: 850

# %%
eff_1 = pd.read_csv('/ssd2/ming/2024COVID/output/5_cnn_10_total_pred_df.csv')
eff_1 = eff_1[['path','total_pred']]
new_path =[]
for i in eff_1.path.values:
    path_ = i.split('/')[-1]
    new_path.append(path_)
eff_1['path'] = new_path
eff_1 = eff_1.sort_values('path').rename(columns={"path":"name","total_pred":"pred"})
file="Submission2"
use_df=eff_1
folder_path="/ssd2/ming/2024COVID/submission"+"/"+file
if not os.path.exists(folder_path):
    os.makedirs(folder_path)
use_df["name"]=use_df["name"].apply(lambda x : x.split("/")[-1])
covid_ct=use_df[use_df["pred"]>0.50].name.values
non_covid_ct=use_df[use_df["pred"]<0.50].name.values

covid_df=pd.DataFrame(covid_ct,columns=["ct_name"])
non_covid_df=pd.DataFrame(non_covid_ct,columns=["ct_name"])
covid_df.sort_values(by=['ct_name'],inplace=True)
non_covid_df.sort_values(by=['ct_name'],inplace=True)

covid_df.to_csv(f"{folder_path}/covid.csv",header=False,index=False)
non_covid_df.to_csv(f"{folder_path}/non-covid.csv",header=False,index=False)
print("covid:",len(covid_df) , "  non_covid:",len(non_covid_df))
# Out:
# covid: 571   non_covid: 842

# %%
eff_2 = pd.read_csv('/ssd2/ming/2024COVID/output/4_cnn_10_total_pred_df.csv')
eff_2 = eff_2[['path','total_pred']]
new_path =[]
for i in eff_2.path.values:
    path_ = i.split('/')[-1]
    new_path.append(path_)
eff_2['path'] = new_path
eff_2 = eff_2.sort_values('path').rename(columns={"path":"name","total_pred":"pred"})
file="Submission3"
use_df=eff_2
folder_path="/ssd2/ming/2024COVID/submission"+"/"+file
if not os.path.exists(folder_path):
    os.makedirs(folder_path)
use_df["name"]=use_df["name"].apply(lambda x : x.split("/")[-1])
covid_ct=use_df[use_df["pred"]>0.50].name.values
non_covid_ct=use_df[use_df["pred"]<0.50].name.values

covid_df=pd.DataFrame(covid_ct,columns=["ct_name"])
non_covid_df=pd.DataFrame(non_covid_ct,columns=["ct_name"])
covid_df.sort_values(by=['ct_name'],inplace=True)
non_covid_df.sort_values(by=['ct_name'],inplace=True)

covid_df.to_csv(f"{folder_path}/covid.csv",header=False,index=False)
non_covid_df.to_csv(f"{folder_path}/non-covid.csv",header=False,index=False)
print("covid:",len(covid_df) , "  non_covid:",len(non_covid_df))
# Out:
# covid: 582   non_covid: 831

# %%
eff_3 = pd.read_csv('/ssd2/ming/2024COVID/output/3_cnn_10_total_pred_df.csv')
eff_3 = eff_3[['path','total_pred']]
new_path =[]
for i in eff_3.path.values:
    path_ = i.split('/')[-1]
    new_path.append(path_)
eff_3['path'] = new_path
eff_3 = eff_3.sort_values('path').rename(columns={"path":"name","total_pred":"pred"})
file="Submission4"
use_df=eff_3
folder_path="/ssd2/ming/2024COVID/submission"+"/"+file
if not os.path.exists(folder_path):
    os.makedirs(folder_path)
use_df["name"]=use_df["name"].apply(lambda x : x.split("/")[-1])
covid_ct=use_df[use_df["pred"]>0.50].name.values
non_covid_ct=use_df[use_df["pred"]<0.50].name.values

covid_df=pd.DataFrame(covid_ct,columns=["ct_name"])
non_covid_df=pd.DataFrame(non_covid_ct,columns=["ct_name"])
covid_df.sort_values(by=['ct_name'],inplace=True)
non_covid_df.sort_values(by=['ct_name'],inplace=True)

covid_df.to_csv(f"{folder_path}/covid.csv",header=False,index=False)
non_covid_df.to_csv(f"{folder_path}/non-covid.csv",header=False,index=False)
print("covid:",len(covid_df) , "  non_covid:",len(non_covid_df))
# Out:
# covid: 544   non_covid: 869

# %%
eff_1 = pd.read_csv('/ssd2/ming/2024COVID/output/5_cnn_10_total_pred_df.csv')
eff_1 = eff_1[['path','total_pred']]
new_path =[]
for i in eff_1.path.values:
    path_ = i.split('/')[-1]
    new_path.append(path_)
eff_1['path'] = new_path
#eff_1 = eff_1.sort_values('path').rename(columns={"path":"name","total_pred":"pred"})

eff_1
# Out:
#               path  total_pred
# 0     11mmey0x.3c4    0.853108
# 1     3kjih4mg.2sr    0.998440
# 2     fld1esi3.gld    0.533595
# 3     0rtjbbvf.3sp    1.000000
# 4     05ewz02d.bpp    0.452695
# ...            ...         ...
# 1408  qpruvets.yjw    0.700046
# 1409  bcdkdvhy.dqm    0.891215
# 1410  cauqmv43.inz    0.045654
# 1411  0ezb31oo.hfz    0.068387
# 1412  vekbjvxc.ylo    0.094530
#
# [1413 rows x 2 columns]

# %%
eff_2 = pd.read_csv('/ssd2/ming/2024COVID/output/4_cnn_10_total_pred_df.csv')
eff_2 = eff_2[['path','total_pred']]
new_path =[]
for i in eff_2.path.values:
    path_ = i.split('/')[-1]
    new_path.append(path_)
eff_2['path'] = new_path
#eff_2 = eff_2.sort_values('path').rename(columns={"path":"name","total_pred":"pred"})
eff_2
# Out:
#               path  total_pred
# 0     11mmey0x.3c4    0.766684
# 1     3kjih4mg.2sr    0.994779
# 2     fld1esi3.gld    0.894714
# 3     0rtjbbvf.3sp    0.999863
# 4     05ewz02d.bpp    0.870900
# ...            ...         ...
# 1408  qpruvets.yjw    0.198432
# 1409  bcdkdvhy.dqm    0.827859
# 1410  cauqmv43.inz    0.034869
# 1411  0ezb31oo.hfz    0.173249
# 1412  vekbjvxc.ylo    0.187573
#
# [1413 rows x 2 columns]

# %%
eff_3 = pd.read_csv('/ssd2/ming/2024COVID/output/3_cnn_10_total_pred_df.csv')
eff_3 = eff_3[['path','total_pred']]
new_path =[]
for i in eff_3.path.values:
    path_ = i.split('/')[-1]
    new_path.append(path_)
eff_3['path'] = new_path
#eff_3 = eff_3.sort_values('path').rename(columns={"path":"name","total_pred":"pred"})
eff_3
# Out:
#               path  total_pred
# 0     11mmey0x.3c4    0.799281
# 1     3kjih4mg.2sr    0.997692
# 2     fld1esi3.gld    0.670168
# 3     0rtjbbvf.3sp    1.000000
# 4     05ewz02d.bpp    0.458505
# ...            ...         ...
# 1408  qpruvets.yjw    0.445174
# 1409  bcdkdvhy.dqm    0.902265
# 1410  cauqmv43.inz    0.035593
# 1411  0ezb31oo.hfz    0.067643
# 1412  vekbjvxc.ylo    0.118162
#
# [1413 rows x 2 columns]

# %%
merged_df = eff_1.merge(eff_2, on="path", suffixes=('_1', '_2')).merge(eff_3, on="path")
merged_df = merged_df.rename(columns={"total_pred": "total_pred_3"})
merged_df['avg'] = merged_df[['total_pred_1', 'total_pred_2', 'total_pred_3']].mean(axis=1)

merged_df.to_csv("/ssd2/ming/2024COVID/submission/merge.csv",header=False,index=False)

merged_df = merged_df[['path','avg']]
new_path =[]
for i in merged_df.path.values:
    path_ = i.split('/')[-1]
    new_path.append(path_)
merged_df['path'] = new_path
merged_df = merged_df.sort_values('path').rename(columns={"path":"path","avg":"avg"})
file="Submission5"
use_df=merged_df
folder_path="/ssd2/ming/2024COVID/submission"+"/"+file
if not os.path.exists(folder_path):
    os.makedirs(folder_path)
use_df["path"]=use_df["path"].apply(lambda x : x.split("/")[-1])
covid_ct=use_df[use_df["avg"]>0.50]
non_covid_ct=use_df[use_df["avg"]<0.50]

covid_df=pd.DataFrame(covid_ct,columns=["path"])
non_covid_df=pd.DataFrame(non_covid_ct,columns=["path"])
covid_df.sort_values(by=['path'],inplace=True)
non_covid_df.sort_values(by=['path'],inplace=True)

covid_df.to_csv(f"{folder_path}/covid.csv",header=False,index=False)
non_covid_df.to_csv(f"{folder_path}/non-covid.csv",header=False,index=False)
print("covid:",len(covid_df) , "  non_covid:",len(non_covid_df))
# Out:
# covid: 560   non_covid: 853
